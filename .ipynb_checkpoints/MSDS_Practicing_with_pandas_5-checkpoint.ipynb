# %% [markdown]
# # Practicing with pandas - 5

# %%
#Imports
import pandas as pd
import numpy as np 
import os
import re

# %%
# Remove comments below and run the cell if changing directories
# os.chdir('../PATHtoFOLDER') #Set working directory
# os.getcwd() #check working directory

# %%
#load data from the file
clients=pd.read_csv('bank-additional.csv', sep=';')

# %%
#check the data
clients.head()
# Out:
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#      contact month day_of_week ...  campaign  pdays  previous     poutcome  \
# 0   cellular   may         fri ...         2    999         0  nonexistent
# 1  telephone   may         fri ...         4    999         0  nonexistent
# 2  telephone   jun         wed ...         1    999         0  nonexistent
# 3  telephone   jun         fri ...         3    999         0  nonexistent
# 4   cellular   nov         mon ...         1    999         0  nonexistent
#
# ...

# %%
clients.tail()
# Out:
#       age         job  marital    education default housing loan    contact  \
# 4114   30      admin.  married     basic.6y      no     yes  yes   cellular
# 4115   39      admin.  married  high.school      no     yes   no  telephone
# 4116   27     student   single  high.school      no      no   no   cellular
# 4117   58      admin.  married  high.school      no      no   no   cellular
# 4118   34  management   single  high.school      no     yes   no   cellular
#
#      month day_of_week ...  campaign  pdays  previous     poutcome  \
# 4114   jul         thu ...         1    999         0  nonexistent
# 4115   jul         fri ...         1    999         0  nonexistent
# 4116   may         mon ...         2    999         1      failure
# 4117   aug         fri ...         1    999         0  nonexistent
# 4118   nov         wed ...         1    999         0  nonexistent
#
#      emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %%
#Look at the structure of the dataframe
clients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4119 entries, 0 to 4118
# Data columns (total 21 columns):
# age               4119 non-null int64
# job               4119 non-null object
# marital           4119 non-null object
# education         4119 non-null object
# default           4119 non-null object
# housing           4119 non-null object
# loan              4119 non-null object
# contact           4119 non-null object
# month             4119 non-null object
# day_of_week       4119 non-null object
# duration          4119 non-null int64
# campaign          4119 non-null int64
# pdays             4119 non-null int64
# previous          4119 non-null int64
# poutcome          4119 non-null object
# emp.var.rate      4119 non-null float64
# cons.price.idx    4119 non-null float64
# cons.conf.idx     4119 non-null float64
# euribor3m         4119 non-null float64
# nr.employed       4119 non-null float64
# y                 4119 non-null object
# ...

# %%
#change column names
#strip potential extra white spaces
#replace '.' and '_'   with spaces, capitalize
clients.columns = clients.columns.str.strip().str.replace('.', ' ').str.replace('_', ' ').str.capitalize()

# %%
#Rename some detaframe columns to give them more descriptive names
clients.rename(columns={'Job': 'Job Type', 'Marital': 'Marital Status', 'Default': 'Is In Default', \
                        'Pdays': 'Days Since Last Contact', 'Previous': 'Previous Contacts',  \
                        'Poutcome': 'Past Outcome', 'Emp var rate': 'Employment Variation Rate', \
                       'Cons price idx': 'Consumer Price Index', 'Cond conf idx': 'Consumer Confidence Index', \
                       'Euribor3m': 'Euribor 3 Month Rate', 'Nr employed': 'Number of Employees', \
                       'Y': 'Has Term Deposit'}, inplace=True)

# %%
#Check results
clients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4119 entries, 0 to 4118
# Data columns (total 21 columns):
# Age                          4119 non-null int64
# Job Type                     4119 non-null object
# Marital Status               4119 non-null object
# Education                    4119 non-null object
# Is In Default                4119 non-null object
# Housing                      4119 non-null object
# Loan                         4119 non-null object
# Contact                      4119 non-null object
# Month                        4119 non-null object
# Day of week                  4119 non-null object
# Duration                     4119 non-null int64
# Campaign                     4119 non-null int64
# Days Since Last Contact      4119 non-null int64
# Previous Contacts            4119 non-null int64
# Past Outcome                 4119 non-null object
# Employment Variation Rate    4119 non-null float64
# Consumer Price Index         4119 non-null float64
# ...

# %%
#Change column types
#convert columns to 'category' type 
columnsToCategories=['Job Type', 'Marital Status', 'Education', 'Is In Default', 'Housing', "Loan", 'Contact', 'Month', 'Day of week', 'Past Outcome']
for i in columnsToCategories:
    clients[i]= clients[i].astype('category')

# %%
#Convert 'Has Term Deposit' to boolean
clients['Has Term Deposit'] = clients['Has Term Deposit'].astype('bool')

# %%
#Check results
clients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4119 entries, 0 to 4118
# Data columns (total 21 columns):
# Age                          4119 non-null int64
# Job Type                     4119 non-null category
# Marital Status               4119 non-null category
# Education                    4119 non-null category
# Is In Default                4119 non-null category
# Housing                      4119 non-null category
# Loan                         4119 non-null category
# Contact                      4119 non-null category
# Month                        4119 non-null category
# Day of week                  4119 non-null category
# Duration                     4119 non-null int64
# Campaign                     4119 non-null int64
# Days Since Last Contact      4119 non-null int64
# Previous Contacts            4119 non-null int64
# Past Outcome                 4119 non-null category
# Employment Variation Rate    4119 non-null float64
# ...

# %%
#Replace '-' and '.' in strings with spaces in the 'Job Type' column
#get rid of trailing  while spaces after processing 'admin.' category
clients['Job Type'] = clients['Job Type'].str.replace('.', ' ').str.strip().astype('category')
clients['Job Type'] = clients['Job Type'].str.replace('-', ' ').astype('category')

# %%
#check results
clients['Job Type']
# Out:
# 0         blue collar
# 1            services
# 2            services
# 3            services
# 4               admin
# 5            services
# 6               admin
# 7        entrepreneur
# 8            services
# 9         blue collar
# 10           services
# 11      self employed
# 12              admin
# 13        blue collar
# 14              admin
# 15           services
# 16              admin
# 17              admin
# 18       entrepreneur
# 19        blue collar
# 20           services
# 21         technician
# 22         technician
# 23         management
# 24         technician
# 25         technician
# 26         technician
# 27        blue collar
# 28              admin
# 29              admin
#             ...
# 4089            admin
# 4090      blue collar
# 4091       management
# 4092      blue collar
# 4093          retired
# 4094      blue collar
# 4095            admin
# 4096         services
# 4097      blue collar
# 4098        housemaid
# ...

# %%
#Replace '.' in strings with spaces in the 'Education' column
clients['Education'] = clients['Education'].str.replace('.', ' ').astype('category')

# %%
#check results
clients['Education']
# Out:
# 0                  basic 9y
# 1               high school
# 2               high school
# 3                  basic 9y
# 4         university degree
# 5         university degree
# 6         university degree
# 7         university degree
# 8       professional course
# 9                  basic 9y
# 10                 basic 6y
# 11                 basic 4y
# 12              high school
# 13                 basic 4y
# 14              high school
# 15        university degree
# 16        university degree
# 17        university degree
# 18        university degree
# 19                 basic 4y
# 20                 basic 6y
# 21              high school
# 22        university degree
# 23              high school
# 24      professional course
# 25      professional course
# 26      professional course
# 27                 basic 6y
# 28                  unknown
# 29        university degree
#                ...
# 4089      university degree
# 4090               basic 4y
# ...

# %%
#Check resulting df
clients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4119 entries, 0 to 4118
# Data columns (total 21 columns):
# Age                          4119 non-null int64
# Job Type                     4119 non-null category
# Marital Status               4119 non-null category
# Education                    4119 non-null category
# Is In Default                4119 non-null category
# Housing                      4119 non-null category
# Loan                         4119 non-null category
# Contact                      4119 non-null category
# Month                        4119 non-null category
# Day of week                  4119 non-null category
# Duration                     4119 non-null int64
# Campaign                     4119 non-null int64
# Days Since Last Contact      4119 non-null int64
# Previous Contacts            4119 non-null int64
# Past Outcome                 4119 non-null category
# Employment Variation Rate    4119 non-null float64
# ...

# %%
#look at the first 20 rows for the first 10 columns 
clients.iloc[:20, :10]
# Out:
#     Age       Job Type Marital Status            Education Is In Default  \
# 0    30    blue collar        married             basic 9y            no
# 1    39       services         single          high school            no
# 2    25       services        married          high school            no
# 3    38       services        married             basic 9y            no
# 4    47          admin        married    university degree            no
# 5    32       services         single    university degree            no
# 6    32          admin         single    university degree            no
# 7    41   entrepreneur        married    university degree       unknown
# 8    31       services       divorced  professional course            no
# 9    35    blue collar        married             basic 9y       unknown
# 10   25       services         single             basic 6y       unknown
# 11   36  self employed         single             basic 4y            no
# ...

# %%
#look at the first 20 rows for the remaining columns
clients.iloc[:20, 10:]
# Out:
#     Duration  Campaign  Days Since Last Contact  Previous Contacts  \
# 0        487         2                      999                  0
# 1        346         4                      999                  0
# 2        227         1                      999                  0
# 3         17         3                      999                  0
# 4         58         1                      999                  0
# 5        128         3                      999                  2
# 6        290         4                      999                  0
# 7         44         2                      999                  0
# 8         68         1                      999                  1
# 9        170         1                      999                  0
# 10       301         1                      999                  0
# 11       148         1                      999                  0
# 12        97         2                      999                  0
# ...

# %%
#look at the last 20 rows for the first 10 columns 
clients.iloc[-20:, :10]
# Out:
#       Age      Job Type Marital Status            Education Is In Default  \
# 4099   58         admin       divorced          high school            no
# 4100   41         admin       divorced          high school            no
# 4101   35  entrepreneur         single    university degree            no
# 4102   31   blue collar         single             basic 9y       unknown
# 4103   43      services        married          high school            no
# 4104   42    technician       divorced  professional course            no
# 4105   47     housemaid        married             basic 4y       unknown
# 4106   45  entrepreneur       divorced             basic 9y            no
# 4107   36         admin        married    university degree       unknown
# 4108   32         admin        married    university degree            no
# 4109   63       retired        married          high school            no
# 4110   53     housemaid       divorced             basic 6y       unknown
# ...

# %%
#look at the last 20 rows for the remaining columns
clients.iloc[-20:, 10:]
# Out:
#       Duration  Campaign  Days Since Last Contact  Previous Contacts  \
# 4099       290         1                      999                  0
# 4100       620         1                      999                  0
# 4101        88         5                      999                  0
# 4102        70         2                      999                  0
# 4103        77         1                      999                  0
# 4104       408         1                      999                  0
# 4105       159         2                      999                  0
# 4106        29         3                      999                  0
# 4107       155        11                      999                  0
# 4108       151         5                      999                  0
# 4109      1386         1                      999                  0
# 4110        85         2                      999                  0
# 4111       131         1                      999                  1
# ...

# %%
# Use groupby() to calculate how many various levels exist in "Days Since Last Contact"
# and how many clients belong in each group. 
clients.groupby('Days Since Last Contact').count()
# Out:
#                           Age  Job Type  Marital Status  Education  \
# Days Since Last Contact
# 0                           2         2               2          2
# 1                           3         3               3          3
# 2                           4         4               4          4
# 3                          52        52              52         52
# 4                          14        14              14         14
# 5                           4         4               4          4
# 6                          42        42              42         42
# 7                          10        10              10         10
# 9                           3         3               3          3
# 10                          8         8               8          8
# 11                          1         1               1          1
# 12                          5         5               5          5
# 13                          2         2               2          2
# ...

# %%
#The "Days Since Last Contact" column contains 3959 values = 999 (out of 4119 total observations) to indicate that the client has not been contacted before
#Deleting or imputing these values will introduce a significant bias in the data set. 
#Depending on the task it might make be useful to keep these values as '999', however for many tasks (e.g., calculating descriptive statistics
# with automatically omnitting non-existent values) it might be better to replace them with NaNs.

#Replace 999 with NaN

clients['Days Since Last Contact'] = clients['Days Since Last Contact'].replace(999, np.NaN)

# %%
#check results
clients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4119 entries, 0 to 4118
# Data columns (total 21 columns):
# Age                          4119 non-null int64
# Job Type                     4119 non-null category
# Marital Status               4119 non-null category
# Education                    4119 non-null category
# Is In Default                4119 non-null category
# Housing                      4119 non-null category
# Loan                         4119 non-null category
# Contact                      4119 non-null category
# Month                        4119 non-null category
# Day of week                  4119 non-null category
# Duration                     4119 non-null int64
# Campaign                     4119 non-null int64
# Days Since Last Contact      160 non-null float64
# Previous Contacts            4119 non-null int64
# Past Outcome                 4119 non-null category
# Employment Variation Rate    4119 non-null float64
# ...

# %%
# Dealing with "unknown" values
# When converting string columns to 'category' data type, "unknown" values present in  
# six columns ('Job Type',  'Marital Status', 'Education', 'Is In Default', 'Housing', and 'Loan'),
# were automatically converted to separate categories - see the output below. 

print(columnsToCategories)
for i in columnsToCategories:
    print(clients[i].cat.categories)
# Out:
# ['Job Type', 'Marital Status', 'Education', 'Is In Default', 'Housing', 'Loan', 'Contact', 'Month', 'Day of week', 'Past Outcome']
# Index(['admin', 'blue collar', 'entrepreneur', 'housemaid', 'management',
#        'retired', 'self employed', 'services', 'student', 'technician',
#        'unemployed', 'unknown'],
#       dtype='object')
# Index(['divorced', 'married', 'single', 'unknown'], dtype='object')
# Index(['basic 4y', 'basic 6y', 'basic 9y', 'high school', 'illiterate',
#        'professional course', 'university degree', 'unknown'],
#       dtype='object')
# Index(['no', 'unknown', 'yes'], dtype='object')
# Index(['no', 'unknown', 'yes'], dtype='object')
# Index(['no', 'unknown', 'yes'], dtype='object')
# Index(['cellular', 'telephone'], dtype='object')
# Index(['apr', 'aug', 'dec', 'jul', 'jun', 'mar', 'may', 'nov', 'oct', 'sep'], dtype='object')
# Index(['fri', 'mon', 'thu', 'tue', 'wed'], dtype='object')
# Index(['failure', 'nonexistent', 'success'], dtype='object')

# %%
# Due to the number of "Unknown" values, in my opinion, it is better to treat them as class labels and not to use deletion or  
# imputation techniques on them until the main goal of the analysis/research questions is known. 
# In some circumstances, "unknown" label can provide additional information (e.g., the client refuses to answer, not interested in further communication
# if he/she was recently contacted and the information is still unknown and "Previous Outcome" == failure). If a client's information is unknown, 
# but he/she has never been contacted, this client might require an additional marketing effort.
